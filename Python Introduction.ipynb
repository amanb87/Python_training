# %% [markdown]
# # Code comparison

# %% [markdown]
# **"Hello World" in JAVA**

# %%
# prints "Hello World"

class HelloWorld {
    public static void main(String[] args) {
        System.out.println("Hello, World!"); 
    }
}

# %% [markdown]
# **"Hello World" in Python**

# %%
print("Hello World")
# Out:
# Hello World

# %%
s = "hello"
s[0]
# Out:
# 'h'

# %% [markdown]
# # English-like syntax

# %%
basket = ["apple", "orange", "pear", "banana"]

for fruit in basket:
    print(fruit)
# Out:
# apple
# orange
# pear
# banana

# %% [markdown]
# # Fun with strings

# %% [markdown]
# A string is a collection of one or more characters put in a single quote, double-quote or triple quote
#
# Examples:
#
# `"hello",`
# `"world",`
# `"python",`
# `"football",`
# `"h",`
# `'g',`
#
# `"""I love Python,
# I love Java too"""`

# %% [markdown]
# **Length of a string**

# %%
len("hello")
# Out:
# 5

# %% [markdown]
# **first character of a string**

# %%
"hello"[0]
# Out:
# 'h'

# %% [markdown]
# **last character of a string**

# %%
"hello"[-1]
# Out:
# 'o'

# %%
"hello"[4]
# Out:
# 'o'

# %%
s = "hello"
print(s)
# Out:
# hello

# %%
s[0]
# Out:
# 'h'

# %%
s[-1]
# Out:
# 'o'

# %%
#Functions take some input and perform some task
# indent
# Out:
# Enter a number: 10

# %%
# conditional statements
# if, elif, else
# while


if(2 and 3): 
    print("Divisible by 2 and 3")
    #do something
elif(2 or 3):
    print("Divisible by 2 or 3")
    #do something
else:
    print("Not divisible by 2 or 3. Aborting!")
    #do something


num % 2 #returns remainder
# Out:
# 0

# %%
num = int(input("Enter a number: "))
if(num % 2 == 0):
    print("Number {0} is divisible by 2".format(num))
else:
    print("Number {0} is not divisible by 2".format(num))
# Out:
# Enter a number: 78
# Number 78 is divisible by 2

# %%
"Bangalore is located at ({latitude}, {longitude})".format(latitude=131.25, longitude=-102.56)
# Out:
# 'Bangalore is located at (131.25, -102.56)'

# %%
# Write a program that will take a number as input and check whether it is divisble by 3 or 5 and print the result displaying the input number dynamically
# Out:
# abc12.0

# %%
num = int(num)
# Out:
# 10

# %%
a = 1 # = is the assignment operator
a = a + 1

# %%
float("6")
# Out:
# 6.0

# %%
a = 1
b = 2
if(a != b):
    print("{x} and {y} are not equal".format(x=a,y=b, z=c, e=f, g=h))
# Out:
# 1 and 2 are not equal

# %%
# f-strings

name = "Harish"
language = "Python"
message = f'{name} is learning {language}'
print(message)
# Out:
# Harish is learning Python

# %%
print(f'There are {6+5} players in a cricket match. A football match is {100-10} minutes long.\nThe weather is awesome{"!"*3}')
# Out:
# There are 11 players in a cricket match. A football match is 90 minutes long.
# The weather is awesome!!!

# %%
a = 1
b = 1
if (a == 3) or (b == 2):
    print(f"Value of b is {b}")

# %%
print((a == 3) or (b == 2)) #True
print((a == 1) and (b == 2)) #True
print((a < 2) or (b > 2)) #True
print((a == 1) and (b == 3)) #False
# Out:
# True
# True
# True
# False

# %%
#What is the difference between == equality operator and is
a is b
# Out:
# True

# %% [markdown]
# Agenda:
# 1. Typecasting
# 2. and, or and not operators
# 3. The is Identity operator
# 4. None type object
# 5. conditional statements
# 6. String methods
# 7. for loops
# 8. while loops
# 9. break and continue statements
# 10. range function

# %%
# Python program to demonstrate nested ternary operator
a, b = 10, 20

if a != b:
    if a > b:
        print("a is greater than b")
    else:
        print("b is greater than a")
else:
    print("Both a and b are equal")
# Out:
# 20 is greater than 10

# %%
a, b = 10, 20

if a < b:
    print(f"Minimum value is {a}")
else:
    print(f"Minimum value is {b}")
# Out:
# Minimum value is 10

# %%
# Program to demonstrate conditional operator
a, b = 10, 20

# Copy value of a in min if a < b else copy b
min_val = f"Minimum value is {a}" if a < b else f"Minimum value is {b}"

print(min_val)
# Out:
# Minimum value is 10

# %%
i = 2

if(i > 2):
    print("i is greater than  2")
elif(i < 2):
    print("i is less than 2")
else:
    print("i is equal to 2")
# Out:
# i is equal to 2

# %%
#Improve this program to list down all vowels in a string
vowels = "aeiou"
hello = "hello"
for char in hello: #char = e
    for vow in vowels: #vow = e
        if char == vow:
            print(f"{char} is a vowel")
        else:
            print(f"{char} is not a vowel")
# Out:
# h is not a vowel
# h is not a vowel
# h is not a vowel
# h is not a vowel
# h is not a vowel
# e is not a vowel
# e is a vowel
# e is not a vowel
# e is not a vowel
# e is not a vowel
# l is not a vowel
# l is not a vowel
# l is not a vowel
# l is not a vowel
# l is not a vowel
# l is not a vowel
# l is not a vowel
# l is not a vowel
# l is not a vowel
# l is not a vowel
# o is not a vowel
# o is not a vowel
# o is not a vowel
# o is a vowel
# o is not a vowel

# %%
#Bingo
jar = 100
board = 0
housie = False
number_called = int(input("I call the number: "))
while((number_called != 0) and (housie == True)):
    print("Game won!")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-ae9080c269af> in <module>
# ----> 1 hello.index("z")
#
# ValueError: substring not found

# %%
a = 1
if(a>2):
    print("a is greater than 2")
else:
    pass

# %%
# Ask user for name and Check if the password he/she entered is 
# 1. 8 characters long. If its not, tell the user(with name) to make a strong 8 character password


print("{:*^100}\n".format("Welcome to online password checker!"))
name = input("Please enter your name: ")
print("Hello, {0}".format(name))
password = input("Enter a strong password. Make sure it is atleast 8 characters long!: ")

while(len(password)<8):
    password = input("The password is less than 8 characters, please re-enter the password: ")       
else:
    print("Thats a good password!\n")
    print("*"*100)
# Out:
# ********************************Welcome to online password checker!*********************************
#
# Please enter your name: Aman
# Hello, Aman
# Enter a strong password. Make sure it is atleast 8 characters long!: 2324
# The password is less than 8 characters, please re-enter the password: 343
# The password is less than 8 characters, please re-enter the password: 3425
# The password is less than 8 characters, please re-enter the password: 121
# The password is less than 8 characters, please re-enter the password: eer
# The password is less than 8 characters, please re-enter the password: 12345678
# Thats a good password!
#
# ****************************************************************************************************

# %%
count = 2
while (count < 3):
    count += 1
    print("Hello Harish")
# Out:
# Hello Harish

# %%
a = int(input('Enter a number (-1 to quit): '))

while (a != -1):
    a = int(input('Enter a number (-1 to quit): '))
# Out:
# Enter a number (-1 to quit): 2
# Enter a number (-1 to quit): 3
# Enter a number (-1 to quit): 4
# Enter a number (-1 to quit): 5
# Enter a number (-1 to quit): 6
# Enter a number (-1 to quit): 7
# Enter a number (-1 to quit): 8
# Enter a number (-1 to quit): 9
# Enter a number (-1 to quit): -1

# %%
while (0<1):
    print("Hello")
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# ...

# %%
book = "Famous five"
f'There are {4**5-20} letters in the book \'{book}\''
# Out:
# "There are 1004 letters in the book 'Famous five'"

# %%
name = input("Enter you name: ")
destination = input("What is your favorite travel destination?: ")
food = input("What is your favorite food?: ")
print("\n\n{:*^100}".format("End of travel enquiry!"))

message = f"Hi {name}. " \
          f"Your favorite travel destination is {destination}. " \
          f"Your favorite food is {food}."
print("\n\nYour responses: ")
print(message)
# Out:
# Enter you name: Sam
# What is your favorite travel destination?: Coorg
# What is your favorite food?: Idli & Sambhar
#
#
# ***************************************End of travel enquiry!***************************************
#
#
# Your responses:
# Hi Sam. Your favorite travel destination is Coorg. Your favorite food is Idli & Sambhar.

# %%
# 'in' operator is called the membership operator
print("hello")
print() #adds a new empty line
print("world")
# Out:
# hello
#
# world

# %%
"hello "*20
# Out:
# 'hello hello hello hello hello hello hello hello hello hello hello hello hello hello hello hello hello hello hello hello '

# %%
"0" in "pa55"
# Out:
# False

# %%
"1" in "pa55"
# Out:
# False

# %%
"5" in "pa55"
# Out:
# True

# %%
s = "hello" * 230 
for i in range(1,len(s),2):
    print(i, s[i])
# Out:
# 1 e
# 3 l
# 5 h
# 7 l
# 9 o
# 11 e
# 13 l
# 15 h
# 17 l
# 19 o
# 21 e
# 23 l
# 25 h
# 27 l
# 29 o
# 31 e
# 33 l
# 35 h
# 37 l
# 39 o
# 41 e
# 43 l
# 45 h
# 47 l
# 49 o
# 51 e
# 53 l
# 55 h
# 57 l
# 59 o
# 61 e
# 63 l
# 65 h
# 67 l
# 69 o
# 71 e
# 73 l
# 75 h
# 77 l
# 79 o
# 81 e
# 83 l
# 85 h
# 87 l
# 89 o
# 91 e
# 93 l
# 95 h
# 97 l
# 99 o
# 101 e
# 103 l
# 105 h
# 107 l
# 109 o
# 111 e
# 113 l
# 115 h
# 117 l
# 119 o
# 121 e
# 123 l
# 125 h
# 127 l
# 129 o
# 131 e
# 133 l
# 135 h
# 137 l
# 139 o
# 141 e
# 143 l
# 145 h
# 147 l
# 149 o
# 151 e
# 153 l
# 155 h
# 157 l
# 159 o
# 161 e
# 163 l
# 165 h
# 167 l
# 169 o
# 171 e
# 173 l
# 175 h
# 177 l
# 179 o
# 181 e
# 183 l
# 185 h
# 187 l
# 189 o
# 191 e
# 193 l
# 195 h
# 197 l
# 199 o
# 201 e
# 203 l
# 205 h
# 207 l
# 209 o
# 211 e
# 213 l
# 215 h
# 217 l
# 219 o
# 221 e
# 223 l
# 225 h
# 227 l
# 229 o
# 231 e
# 233 l
# 235 h
# 237 l
# 239 o
# 241 e
# 243 l
# 245 h
# 247 l
# 249 o
# 251 e
# 253 l
# 255 h
# 257 l
# 259 o
# 261 e
# ...

# %%
#Convert Fahrenheit to celsius
#c = (f - 32) * (5/9)
# What if user enters any alphabet or symbol or special character as input
# What is user input is blank
# What if user has temprature in Celsius
# What if user enters a very large negative or positive number
# Ask user's name
# input is Mandatory

f = float(input("Enter the temperature in Fahrenheit: "))
c = round((f - 32) * (5/9),2)

print(f"Your temperature in Celsius is: {c}")
# Out:
# Enter the temperature in Fahrenheit:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-852b99944c93> in <module>
#       8 # input is Mandatory
#       9
# ---> 10 f = float(input("Enter the temperature in Fahrenheit: "))
#      11 c = round((f - 32) * (5/9),2)
#      12
#
# ValueError: could not convert string to float: ''

# %% [markdown]
# Write a Password checker:
# - minimum 8 characters
# - must have atleast one number
# - must have atleast one uppercase character
# - must have atleast one special symbol: ><&@#$
# - must not be a dictionary word - optional
# - password cannot be blank
# - very large inputs not allowed -  maximum password length is 15 characters
# - input is mandatory
